# %% [markdown]
# ## Søk og konkordanser, korpus

# %%
"https://raw.githubusercontent.com/nsonnad/base16-ipython-notebook/master/ipython-3/output/base16-google-light.css"

# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu
mu.css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# ...

# %% [markdown]
# Søk i hele samlingen, begrens i hvilke typer bøker

# %%
nb.concordance(word= '«', subject='fangst', corpus='bok', after=10, before=3, kind='json')
# Out:
# [{'after': 'Håper dere kan more dere over den og få inspirasjon',
#   'author': 'Frederiksen, Thomas',
#   'before': 'denne bemerkningen :',
#   'title': 'Grønlandske dagboksblader',
#   'urn': 'http://www.nb.no/items/URN:NBN:no-nb_digibok_2008060200036',
#   'word': '«',
#   'year': 1980},
#  {'after': "sr- * - e - < * T ' '",
#   'author': 'Frederiksen, Thomas',
#   'before': '* - ?',
#   'title': 'Grønlandske dagboksblader',
#   'urn': 'http://www.nb.no/items/URN:NBN:no-nb_digibok_2008060200036',
#   'word': '«',
#   'year': 1980},
#  {'after': '( Ur ^ v * * W !',
#   'author': 'Frederiksen, Thomas',
#   'before': '^ ^ ^',
#   'title': 'Grønlandske dagboksblader',
#   'urn': 'http://www.nb.no/items/URN:NBN:no-nb_digibok_2008060200036',
#   'word': '«',
#   'year': 1980},
#  {'after': '^ / ^ 7 « " * - * -',
#   'author': 'Frederiksen, Thomas',
#   'before': None,
#   'title': 'Grønlandske dagboksblader',
#   'urn': 'http://www.nb.no/items/URN:NBN:no-nb_digibok_2008060200036',
# ...

# %% [markdown]
# Bygg et korpus

# %%
nno = nb.book_corpus(lang = 'nno', limit = 50000)

# %%
sjark = nb.refine_book_urn(urns=nb.pure_urn(nno), words=['sjark', "Sjark"], limit=100)

# %%
nb.urn_concordance(word=['sjark', 'sjarken', 'sjarkene', 'sjarker'], urns=nb.refine_book_urn(urns=nb.pure_urn(nno), words=['sjark', "Sjark"], limit=50))
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009120200071?searchText=['sjark', 'sjarken', 'sjarkene', 'sjarker']' target='_blank' style='text-decoration:none'>Geografi, Karlsen, Ole G., 1998</a>
#                 </td>
#                 <td>til dømes sjarkar . Ein</td>
#                 <td>sjark</td>
#                 <td style='text-align:left'>har 1 - 3 mann</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009120200071?searchText=['sjark', 'sjarken', 'sjarkene', 'sjarker']' target='_blank' style='text-decoration:none'>Geografi, Karlsen, Ole G., 1998</a>
#                 </td>
#                 <td>14 kvinner som åtte eigen</td>
#                 <td>sjark</td>
#                 <td style='text-align:left'>med kvote .</td>
#             </tr>
# <tr>
#                 <td>
# ...

# %%
nb.word_paradigm('sjark')
# Out:
# [['subs', ['sjark', 'sjarken', 'sjarkene', 'sjarker']]]

# %%
nb.concordance('Sjark', lang='nno')

# %%
import dhlab.graph_networkx_louvain as gnl

# %%
h = nb.make_graph('helse', cutoff=12)

# %%
gnl.show_communities(h)
# Out:
# miljø-kultur :  miljø, kultur, idrett, næring, oppvekst, historie, klima, friluftsliv, sikkerhet, samferdsel, energi, religion, natur, fritid, teknikk, utvikling
#
# mat-Mat :  mat, Mat, vin, kaffe, kaffi, tobakk, husly, medisiner, vann, drikke, kopp, klær
#
# helse-kropp :  helse, kropp, velferd, liv, sosial, telekom, sjel, ånd, it, sinn, økonomisk, sysselsetting, verdiskaping, hode, død, velstand, utseende, hjerne, sex, ansikt, seksualitet, dod, kulturell, politisk, lære, helsefag
#
# kosthold-ernæring :  kosthold, ernæring, hygiene, fysisk, livsstil, trening, landbruk
#
# trivsel-livskvalitet :  trivsel, livskvalitet, sunnhet, velvære, Helse, trygghet, glede, livsglede, trim, levekår, skjønnhet, styrke, komfort, arbeidsevne, vekst, mestring, fremgang, hygge, vitalitet
#
# omsorg-pleie :  omsorg, pleie, kjærlighet, pleie-, godhet
#
# sosiale-okonomiske :  sosiale, okonomiske, økonomiske, humanitære, kulturelle, helsemessige, politiske
#
# ...

# %%
gnl.show_cliques(h)
# Out:
# (3, 1) idrett, velvære, tobakk, glede, sunnhet, omsorg, helse, natur, fritid, levekår, liv, utvikling, miljø, livskvalitet, kultur, velferd, sosiale, helse-, fysisk, ernæring, skjønnhet, arbeidsevne, kosthold, mat, trivsel, Helse, vekst, vitalitet, trygghet, sosial, næring, hygiene
#
# (4, 1) miljø, livskvalitet, velvære, velferd, sunnhet, helse, trivsel, trygghet
#
# (4, 2) ernæring, helse, kosthold, mat

# %%
nb.central_betweenness_characters(h, 20)
# Out:
# [('Os', 0.5697005639862784),
#  ('Bergen', 0.17455200883772312),
#  ('Tynset', 0.1531100645386359),
#  ('Røros', 0.15305541019826735),
#  ('Fana', 0.12583202511773942),
#  ('Askøy', 0.10837170765742195),
#  ('Tysnes', 0.09089133089133095),
#  ('Folldal', 0.07754927612070471),
#  ('Engerdal', 0.06945403802546661),
#  ('Nordhordland', 0.06581603581603582),
#  ('Fusa', 0.05791208791208788),
#  ('Samnanger', 0.041270713413570505),
#  ('Holtålen', 0.04017268445839876),
#  ('Sotra', 0.031383801383801396),
#  ('Tolga', 0.02909674981103558),
#  ('Degernes', 0.02356532356532357),
#  ('Midtun', 0.010256410256410258),
#  ('Fyllingsdalen', 0.010012210012210011),
#  ('Austevoll', 0.00903947903947904),
#  ('Dalsbygda', 0.006125356125356126)]

# %%
import requests
import pandas as pd

def collocation(
    word, 
    yearfrom=2010, 
    yearto=2018, 
    before=3, 
    after=3, 
    limit=1000, 
    corpus='avis',
    lang='nob',
    title='%',
    ddk='%', 
    subtitle='%'):
    """Defined collects frequencies for a given word"""
    
    data =  requests.get(
        "https://api.nb.no/ngram/collocation", 
        params={
            'word':word,
            'corpus':corpus, 
            'yearfrom':yearfrom, 
            'before':before,
            'after':after,
            'limit':limit,
            'yearto':yearto,
        'title':title,
        'ddk':ddk,
        'subtitle':subtitle}).json()
    return data['freq'],data['doc'], data['dist'] 


def urn_coll(word, urns=[], after=5, before=5, limit=1000):
    """Find collocations for word in a set of book URNs. Only books at the moment"""
    
    if isinstance(urns[0], list):  # urns assumed to be list of list with urn-serial as first element
        urns = [u[0] for u in urns]
        
    r = requests.post("https://api.nb.no/ngram/urncolldist", json={'word':word, 'urns':urns, 
                                                                   'after':after, 'before':before, 'limit':limit})
    return r.json()

# %%
dist = collocation('muslimer', before=0, after=10)[2]

# %%
d = nb.frame(dist)

# %%
d[d > 2].sort_values(by = 0).loc['innvandret']
# Out:
# 0    8.0
# Name: innvandret, dtype: float64

# %%
korpus = nb.book_corpus(ddk="641%")

# %%
df = nb.frame(urn_coll(urns=nb.pure_urn(korpus), word='hvitvin'))

# %%
df.transpose()
# Out:
#                 0          1
# %             3.0  -1.500000
# '             3.0   1.000000
# (             4.0   3.333333
# )             2.0   4.000000
# ,            44.0   1.111111
# -             1.0   4.000000
# .            37.0  -0.300000
# /            24.0  -1.454545
# 1            59.0  -4.666667
# 100           2.0  -1.500000
# 11            2.0  -2.000000
# 150           1.0   1.000000
# 176           2.0 -10.000000
# 177           2.0   2.000000
# 2            56.0  -1.916667
# 2,5           2.0  -2.000000
# 21            2.0   1.000000
# 250           2.0   5.000000
# 3             7.0   0.166667
# 300           1.0  -5.000000
# 4            14.0  -0.250000
# 450           1.0   1.000000
# 48            1.0   2.000000
# 5             2.0   1.000000
# 50            1.0  -5.000000
# 6             4.0   0.500000
# 7             4.0  -1.333333
# 72            2.0  -1.000000
# 75            1.0   5.000000
# 8             1.0   1.000000
# ...           ...        ...
# ...

# %%
df[df > 1].sort_values(by=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-146-73769d1fabae> in <module>
# ----> 1 df[df > 1].sort_values(by=0)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4717
#    4718             by = by[0]
# -> 4719             k = self._get_label_or_level_values(by, axis=axis)
#    4720
#    4721             if isinstance(ascending, (tuple, list)):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1704             values = self.axes[axis].get_level_values(key)._values
#    1705         else:
# -> 1706             raise KeyError(key)
#    1707
#    1708         # Check for duplicates
#
# KeyError: 0
