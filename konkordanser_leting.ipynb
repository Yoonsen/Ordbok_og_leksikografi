# %% [markdown]
# ## Søk og konkordanser, korpus

# %%
"https://raw.githubusercontent.com/nsonnad/base16-ipython-notebook/master/ipython-3/output/base16-google-light.css"

# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu
mu.css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# ...

# %% [markdown]
# Bygg et korpus

# %%
nno = nb.book_corpus(lang = 'nno', limit = 50000)

# %%
sjark = nb.refine_book_urn(urns=nb.pure_urn(nno), words=['sjark', "Sjark"], limit=100)

# %%
nb.urn_concordance(word=['sjark', 'sjarken', 'sjarkene', 'sjarker'], urns=nb.refine_book_urn(urns=nb.pure_urn(nno), words=['sjark', "Sjark"], limit=50))
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009120200071?searchText=['sjark', 'sjarken', 'sjarkene', 'sjarker']' target='_blank' style='text-decoration:none'>Geografi, Karlsen, Ole G., 1998</a>
#                 </td>
#                 <td>til dømes sjarkar . Ein</td>
#                 <td>sjark</td>
#                 <td style='text-align:left'>har 1 - 3 mann</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009120200071?searchText=['sjark', 'sjarken', 'sjarkene', 'sjarker']' target='_blank' style='text-decoration:none'>Geografi, Karlsen, Ole G., 1998</a>
#                 </td>
#                 <td>14 kvinner som åtte eigen</td>
#                 <td>sjark</td>
#                 <td style='text-align:left'>med kvote .</td>
#             </tr>
# <tr>
#                 <td>
# ...

# %%
nb.word_paradigm('sjark')
# Out:
# [['subs', ['sjark', 'sjarken', 'sjarkene', 'sjarker']]]

# %%
nb.concordance('Sjark', lang='nno')
