# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu
#mu.update('collocations', overwrite=True)
from collocations import urn_coll, collocation
from numpy import log

# %%
def dist(obs_mean, expected, freq):
    factor = ((freq-1)/(freq))*obs_mean
    ratio = obs_mean/(obs_mean - factor)
    return obs_mean + (expected - obs_mean)/ratio

# %%
corpus = nb.book_corpus(words=['selge', 'selger', 'solgte'], limit=100)

# %%
corpus
# Out:
#               urn                 author  \
# 0   2012011205078     Viestad, Konrad M.
# 1   2011011208105        Dahl, Svenn-Åge
# 2   2012062605015      Läckberg, Camilla
# 3   2011051608175         Ardagh, Philip
# 4   2009020600058           Wexels, W.A.
# 5   2011010508015             Eggum, Jan
# 6   2012082206002
# 7   2013120205190
# 8   2011021508006             Roald, Jan
# 9   2016101848059        Haukenæs, Th.S.
# 10  2010060803035  Antunes, António Lobo
# 11  2012070205088     Vibe Jensen, Gurli
# 12  2012100807005      Folden, Harald E.
# 13  2009120800095
# 14  2014111008161             Iams, Jack
# 15  2012120508250         Golombek, Rolf
# 16  2015102908102
# 17  2016100408077
# 18  2016083008028        Bjørneboe, Jens
# 19  2007071001010      Dale, Erling Lars
# 20  2012030508026       Gabrielsen, Egil
# 21  2012070208017
# 22  2013100305010   Sandberg, Kristín A.
# 23  2010041903055            Gates, Bill
# 24  2014021805050     Andersen, Svein S.
# 25  2008072204109            Nygaard, M.
# 26  2011070505024   Tvedt, Morten Walløe
# 27  2011032506208          Grøn, Fredrik
# 28  2011120208144    Frich, Øvre Richter
# 29  2014011008041   Nilssen, Einar Johs.
# ..            ...                    ...
# 70  2011081108157       McAllister, Anne
# 71  2008051604005         Grimberg, Carl
# 72  2007070300054      Mathiesen, Thomas
# 73  2007112101019          Belbin, David
# 74  2007073100030     Svendsrud, Asbjørn
# 75  2007070501066
# 76  2013120406076        Deaver, Jeffery
# 77  2012080808020
# 78  2015050408110      Vold, Karin Beate
# 79  2007110504061        Knudtsen, Ingar
# 80  2012042008044              Aga, Elsa
# 81  2011070506037       Gunnerud, Jørgen
# 82  2009033000008    Millstein, Marianne
# 83  2008103110002    Asbjørnsen, P. Chr.
# 84  2007121000063         Holst, Kirsten
# 85  2011053106008          Venheim, Rolf
# 86  2016090648013
# 87  2012061505021        Fønhus, Mikkjel
# 88  2016072248112       Flood, Jørgen W.
# 89  2010121706037         Ørbeck, Morten
# 90  2016052608149       Simenon, Georges
# 91  2007042401012         Thorsrud, Olav
# 92  2009020404011        Wegge, Kathrine
# 93  2008102200082  Rushford, Patricia H.
# 94  2006081000034       Bugge, Alexander
# 95  2011062108074       Bleikvassli, Odd
# 96  2009051303010           Tornow, Carl
# 97  2008051304075        Moberg, Vilhelm
# 98  2006120600041       Anker, Nini Roll
# 99  2014111807597       Wahlstrøm, Frits
#
#                                                 title  year
# 0                                  Husbyggingsteknikk  1978
# 1                                        Dekruttering  1996
# 2                                         Predikanten  2006
# 3                Fergals fall, eller Raskeste vei ned  2003
# 4                        liden Bibelhistorie for Børn  1839
# 5                              Mellom borger og bohem  1991
# 6                Import og distribusjon av spillefilm  1978
# 7                           Håndbok i kirkegårdsdrift  1975
# 8                 Introduction au français commercial  1998
# 9                                     Barndomshjemmet  1890
# 10                           Tingenes naturlige orden  1997
# 11                               Kan man synge i sne?  1983
# 12                     Til fjells i fortidens fotefar  1992
# 13                            Nasjonalatlas for Norge  1997
# 14                               bord for fire, takk!  1940
# 15  Modeller og datakilder for elektrisitets- og g...  1996
# 16                        Bygdebok for Lierne kommune  2007
# 17                                     Havstein kirke  1957
# 18                                  Samlede skuespill  1973
# 19                     Skolereformene og næringslivet  1974
# 20                                Byenes åpne arealer  1973
# 21  Normer for regnskapsoppstilling og bearbeidels...  1988
# 22                                Iris, skjebnehjulet  2010
# 23                      Ledelse med t@nkens hastighet  1999
# 24  Seks teser om organisasjon og ledelse i norske...  1988
# 25  Kortfattet Fremstilling af det norske Landsmaa...  1867
# 26                           Å skrive jus til eksamen  2004
# 27                        Brødets saga gjennem tidene  1939
# 28                                           Gullåren  1985
# 29                                   Norsk Grammatikk  1926
# ..                                                ...   ...
# 70                              Hans store kjærlighet  1997
# 71                        Menneskenes liv og historie  1956
# 72                              skjulte disiplinering  1978
# 73                                      Lammende tåke  1993
# 74                                        Skogøkonomi  1969
# 75                              Norges kulturhistorie  1980
# 76                                  Det tolvte kortet  2008
# 77  Innstilling og forskrifter for budsjettoppstil...  1952
# 78                            Norsk barnebokinstitutt  2011
# 79                                    Nord for Saigon  1992
# 80                                    Da klokka klang  1973
# 81                                    Til odel og eie  2004
# 82             Utshani BuyaKhuluma (grasrota snakker)  2002
# 83                               Norske Folke-Eventyr  1868
# 84                                    Det levende lik  1993
# 85                                        Regnereisen  1997
# 86                                       Vi bor i lag  2005
# 87                     Røyskatt og andre fortellinger  1989
# 88                                  Norges Apothekere  1908
# 89  Trelastindustrien som energiprodusent, -bruker...  1996
# 90                                 Maigret går på bar  1980
# 91                                            Fløyten  1966
# 92               Alle barn har rett til å gå på skole  2001
# 93                                         Dødsfellen  2000
# 94  Studier over de norske Byers Selvstyre og Hand...  1899
# 95                                        Bleikvassli  2002
# 96                        Blondel, den uskyldig dømte  1899
# 97                                    Siste brev hjem  1959
# 98                                   Under skraataket  1927
# 99                    Blomster-Nilsen i sorg og glede  2011
#
# [100 rows x 4 columns]

# %%
colls = dict()
for character in "selge selger solgte".split():
    colls[character] = urn_coll(character, nb.pure_urn(corpus), before=0, after=10)

# %%
frames = dict()
for c in colls:
    frames[c] = nb.frame({'dist':colls[c][1], 'freq':colls[c][0]}).transpose()

# %%
for c in frames:
    frames[c]['score'] = dist(frames[c].dist, 5.5, frames[c].freq)

# %%
inspect = lambda harry, w: harry.loc[w] if w in harry.index else 0

# %%
for c in frames:
    print(c, inspect(frames[c]['score'], 'bilen'))
# Out:
# selge 0
# selger 0
# solgte 3.5

# %%
for c in frames:
    print(c, inspect(frames[c]['score'], 'til'))
# Out:
# selge 4.7703146374829
# selger 3.4337971747838925
# solgte 4.654693221131755

# %%
for c in frames:
    print(c, inspect(frames[c]['score'], 'kroner'))
# Out:
# selge 0
# selger 5.625
# solgte 7.125

# %%
for c in frames:
    print(c, inspect(frames[c]['score'], ','))
# Out:
# Harry 5.1400519966485945
# Hermine 5.306617400390301
# Humlesnurr 4.985404367635462
# Ronny 5.169729492132541
# Malfang 4.872838915757096
# Slur 5.106331731091962
# Gygrid 4.734894141796383

# %%
check ('måpte')
# Out:
# {'Hermine': 1.7499999999999998,
#  'Humlesnurr': 3.8333333333333335,
#  'Ronny': 1.7499999999999998,
#  'Malfang': 3.0604395604395602,
#  'Slur': 5.5}

# %%
check ('lengsel')
# Out:
# {'Gygrid': 5.5}

# %%
check ('.')
# Out:
# {'Harry': 4.89855117098017,
#  'Hermine': 4.321076379353063,
#  'Humlesnurr': 4.5050727654934315,
#  'Ronny': 4.508710426008721,
#  'Malfang': 5.03739403340547,
#  'Slur': 4.874322895066954,
#  'Gygrid': 4.845083491478908}

# %%
check ('slo')
# Out:
# {'Harry': 5.928571428571429,
#  'Hermine': 6.111111111111112,
#  'Humlesnurr': 6.625,
#  'Ronny': 2.291666666666667,
#  'Malfang': 6.680555555555555,
#  'Slur': 3.0142857142857142,
#  'Gygrid': 2.8979591836734695}

# %%
check ('sint')
# Out:
# {'Harry': 5.5,
#  'Humlesnurr': 3.7,
#  'Malfang': 4.961428571428572,
#  'Slur': 5.32,
#  'Gygrid': 3.8125000000000004}

# %%
check('bistert')
# Out:
# {'Harry': 1.8333333333333333,
#  'Hermine': 1.3750000000000002,
#  'Humlesnurr': 3.8333333333333335,
#  'Ronny': 7.833333333333333,
#  'Slur': 5.5,
#  'Gygrid': 2.5}

# %%
show = lambda harry, cutoff: harry[harry.freq > cutoff].sort_values(by='score')

# %%
show(frames['Harry'][frames['Harry']['dist']> 8], 5)[:20]
# Out:
#                           dist  freq     score
# P                     8.125000   6.0  7.687500
# Dagens                8.166667   6.0  7.722222
# befippelsen           8.166667   6.0  7.722222
# flaske                8.142857   7.0  7.765306
# boa                   8.142857   8.0  7.812500
# ITAPITTEI             8.055556  12.0  7.842593
# 4                     8.125000  11.0  7.886364
# Lykke                 8.285714   7.0  7.887755
# død                   8.100000  15.0  7.926667
# >                     8.333333   7.0  7.928571
# digre                 8.153846  13.0  7.949704
# fjor                  8.222222  10.0  7.950000
# S                     8.400000   7.0  7.985714
# Snart                 8.200000  13.0  7.992308
# Inne                  8.500000   6.0  8.000000
# brak                  8.250000  11.0  8.000000
# Molly                 8.500000   6.0  8.000000
# dødsensdagsselskapet  8.500000   6.0  8.000000
# Nestors               8.500000   6.0  8.000000
# gammel                8.250000  11.0  8.000000

# %%
inspect(frames['Humlesnurr'], 'Ronny')
# Out:
# dist      6.287302
# freq     82.000000
# score     6.277700
# Name: Ronny, dtype: float64

# %%
kreft_right_20 = dict()
step = 3
for year in range(1950, 1989, step):
    print(year, year + step)
    kreft_right_20[(year, year + step)] = collocation('kreft', yearfrom=year, yearto=year + step, corpus='avis', before= 0, after = 20)
# Out:
# 1950 1953
# 1953 1956
# 1956 1959
# 1959 1962
# 1962 1965
# 1965 1968
# 1968 1971
# 1971 1974
# 1974 1977
# 1977 1980
# 1980 1983
# 1983 1986
# 1986 1989

# %%
def create_frame(coll, expected):
    df = nb.frame(nb.frame(coll).transpose(), 'freq doc dist'.split())
    df['score'] = dist(df['dist'], expected, df['freq'])
    return df

def colls2df(colls, expected):
    colls_df = dict()
    for c in colls:
        colls_df[c] = create_frame(colls[c], expected)
    return colls_df

    
def make_collocations(word, yeafrom, yearto, step, before = 0, after = 10):
    colls = dict()
    step = 3
    for year in range(perio[0], period[1], step):
        print('behandler: ', year, year + step)
        colls[(year, year + step)] = collocation('kreft', yearfrom=year, yearto=year + step, corpus='avis', before= 0, after = 20)
    if before == 0:
        pos_from = -1
    else:
        pos_from = -before
    if after == 0:
        pos_to = 1
    else:
        post_to = after
    colls_df = colls2df(colls, (pos_to + pos_from)/2)
    return colls_df                


score_df = lambda df: nb.frame({x:df[x]['score'] for x in df }).transpose()
display_vals = lambda kr_df, word, clip = 0: kr_df[kr_df >= clip].loc[word]
show_frame = lambda df, colnum = 0,  clip = 0, up = True: df[df >= clip].sort_values(by = df.columns[colnum], ascending=up)

# %%
kreft_right_20 = dict()
step = 3
for year in range(1950, 1989, step):
    print(year, year + step)
    kreft_right_20[(year, year + step)] = collocation('kreft', yearfrom=year, yearto=year + step, corpus='avis', before= 0, after = 20)

# %%
kreft_left = dict()
step = 3
for year in range(1950, 1990, step):
    print(year, year + step)
    kreft_left[(year, year + step)] = collocation('kreft', yearfrom=year, yearto=year + step, corpus='avis', before= 10, after = 0)
# Out:
# 1950 1953
# 1953 1956
# 1956 1959
# 1959 1962
# 1962 1965
# 1965 1968
# 1968 1971
# 1971 1974
# 1974 1977
# 1977 1980
# 1980 1983
# 1983 1986
# 1986 1989
# 1989 1992

# %%
kreft_right_df = colls2df(kreft_right, 5.5)

# %%
kreft_left_df = colls2df(kreft_left, -5.5)

# %%
kreft_right_df_20 = colls2df(kreft_right_20, 10.5)

# %%
kl_df = nb.frame({x:kreft_left_df[x]['score'] for x in kreft_left_df }).transpose()

# %%
kr_df = nb.frame({x:kreft_right_df[x]['score'] for x in kreft_right_df }).transpose()

# %%
kr_df_20 = nb.frame({x:kreft_right_df_20[x]['score'] for x in kreft_right_df_20 }).transpose()

# %%
display_vals(kr_df, 'kreft')
# Out:
# 1950  1953    6.369168
# 1953  1956    7.574082
# 1956  1959    7.554981
# 1959  1962    6.210233
# 1962  1965    7.192111
# 1965  1968    6.990321
# 1968  1971    6.883849
# 1971  1974    6.674145
# 1974  1977    7.056645
# 1977  1980    6.903405
# 1980  1983    7.220245
# 1983  1986    7.564688
# 1986  1989    6.945288
# Name: kreft, dtype: float64

# %%
display_vals(kl_df, ',', clip = - 10)
# Out:
# 1950  1953   -5.843677
# 1953  1956   -5.888285
# 1956  1959   -5.704103
# 1959  1962   -5.763687
# 1962  1965   -5.853601
# 1965  1968   -6.024753
# 1968  1971   -5.769897
# 1971  1974   -4.917184
# 1974  1977   -5.880763
# 1977  1980   -6.150814
# 1980  1983   -6.066827
# 1983  1986   -5.978104
# 1986  1989   -5.829407
# 1989  1992   -5.927462
# Name: ,, dtype: float64

# %%
kr_df_20[kr_df_20 >= 0].sort_values(by=kr_df_20.columns[12]).loc['.']
# Out:
# 1950  1953    8.810991
# 1953  1956    8.990411
# 1956  1959    9.187679
# 1959  1962    9.203099
# 1962  1965    9.552017
# 1965  1968    9.033921
# 1968  1971    8.639730
# 1971  1974    8.530482
# 1974  1977    8.689690
# 1977  1980    9.287126
# 1980  1983    9.495160
# 1983  1986    9.624627
# 1986  1989    9.181418
# Name: ., dtype: float64

# %%
show_frame(kl_df, colnum=11, clip = -30, up=False)[0:20].fillna(-10).style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
#     #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row0_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row0_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row0_col3 {
#             background-color:  #69add5;
#             color:  #000000;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row0_col4 {
#             background-color:  #68acd5;
#             color:  #000000;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row0_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row0_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row0_col7 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row0_col8 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row0_col9 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row0_col10 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row0_col11 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row0_col12 {
#             background-color:  #083776;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row0_col13 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row1_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row1_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row1_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row1_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row1_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row1_col6 {
#             background-color:  #0a549e;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row1_col7 {
#             background-color:  #083979;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row1_col8 {
#             background-color:  #08326e;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row1_col9 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row1_col10 {
#             background-color:  #083370;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row1_col11 {
#             background-color:  #08519c;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row1_col12 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row1_col13 {
#             background-color:  #083471;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row2_col0 {
#             background-color:  #084082;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row2_col1 {
#             background-color:  #083370;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row2_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row2_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row2_col4 {
#             background-color:  #083a7a;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row2_col5 {
#             background-color:  #083979;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row2_col6 {
#             background-color:  #083979;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row2_col7 {
#             background-color:  #083b7c;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row2_col8 {
#             background-color:  #083776;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row2_col9 {
#             background-color:  #083b7c;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row2_col10 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row2_col11 {
#             background-color:  #1865ac;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row2_col12 {
#             background-color:  #083979;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row2_col13 {
#             background-color:  #083471;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row3_col0 {
#             background-color:  #083674;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row3_col1 {
#             background-color:  #083573;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row3_col2 {
#             background-color:  #083471;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row3_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row3_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row3_col5 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row3_col6 {
#             background-color:  #083b7c;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row3_col7 {
#             background-color:  #083e81;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row3_col8 {
#             background-color:  #083370;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row3_col9 {
#             background-color:  #083471;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row3_col10 {
#             background-color:  #083a7a;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row3_col11 {
#             background-color:  #2e7ebc;
#             color:  #000000;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row3_col12 {
#             background-color:  #083471;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row3_col13 {
#             background-color:  #08488e;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row4_col0 {
#             background-color:  #0e58a2;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row4_col1 {
#             background-color:  #084082;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row4_col2 {
#             background-color:  #08488e;
#             color:  #f1f1f1;
#         }    #T_2763f6f8_f387_11e9_8dcb_000acd2bfab2row4_col3 {
#             background-color:  #0a539e;
#             colo

# %%
from matplotlib import colors

# %%
cmap = "Blues"

# %%
show_frame(kr_df, colnum=11, clip = 0, up=True)[0:40].fillna(10).style.background_gradient(cmap='Blues_r',axis=0)
# Out:
# <style  type="text/css" >
#     #T_aef508dc_f388_11e9_a140_000acd2bfab2row0_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row0_col2 {
#             background-color:  #4d99ca;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row0_col3 {
#             background-color:  #549fcd;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row0_col4 {
#             background-color:  #083979;
#             color:  #f1f1f1;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row0_col5 {
#             background-color:  #0b559f;
#             color:  #f1f1f1;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row0_col6 {
#             background-color:  #125da6;
#             color:  #f1f1f1;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row0_col7 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row0_col8 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row0_col9 {
#             background-color:  #084488;
#             color:  #f1f1f1;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row0_col10 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row0_col11 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row0_col12 {
#             background-color:  #083573;
#             color:  #f1f1f1;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row1_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row1_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row1_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row1_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row1_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row1_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row1_col7 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row1_col8 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row1_col9 {
#             background-color:  #4f9bcb;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row1_col10 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row1_col11 {
#             background-color:  #1b69af;
#             color:  #f1f1f1;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row1_col12 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row2_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row2_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row2_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row2_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row2_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row2_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row2_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row2_col7 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row2_col8 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row2_col9 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row2_col10 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row2_col11 {
#             background-color:  #1d6cb1;
#             color:  #f1f1f1;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row2_col12 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row3_col0 {
#             background-color:  #4f9bcb;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row3_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row3_col2 {
#             background-color:  #4d99ca;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row3_col3 {
#             background-color:  #69add5;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row3_col4 {
#             background-color:  #519ccc;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row3_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row3_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row3_col7 {
#             background-color:  #4d99ca;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row3_col8 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row3_col9 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row3_col10 {
#             background-color:  #4b98ca;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row3_col11 {
#             background-color:  #3787c0;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row3_col12 {
#             background-color:  #5ca4d0;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row4_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row4_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row4_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row4_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row4_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row4_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row4_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_aef508dc_f388_11e9_a140_000acd2bfab2row4_col7 {
#             background-color:  #f7fbff;
#             color:
